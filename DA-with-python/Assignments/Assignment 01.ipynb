# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
print("Name\t:","ABUBAKER","\nFATHER NAME\t:","SHAHZAD ISLAM AWAN","\nDate of birth\t:","20-04-2007")
# Out:
# Name	: ABUBAKER
# FATHER NAME	: SHAHZAD ISLAM AWAN
# Date of birth	: 20-04-2007

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
# BIO
Name ="ABUBAKER SHAHZAD AWAN"
Study=" I am a student iif bsai 4 semester"
print(Name)
print(Study)
# Out:
# ABUBAKER SHAHZAD AWAN
#  I am a student iif bsai 4 semester

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
# Arithematic operators
a=12
d=90
print(a+d)
print(a-d)
print(a/d)
print(a*d)
print(a**d)
print(a//d) # no valuue after decimal point.
print(a%d) # leftover after the first divide.
#Comparsion
print(a==d)# equal
print(a!=d)#notequal
print(a>d)#greater then
print(a<d)# lower then
#Logical operators AND ,OR  , NOT 
# AND WHEN BOTH CONDITION TRUE,OR WHEN ONE ATLEAST TRUE , NOT WILL MAKE THEM OPPOSITE .
c=30 
print(a==d and a > c)
print(d>c or c==a)
print(a==d  and not a > c)
print(d>c  or not c==a)
# Out:
# 102
# -78
# 0.13333333333333333
# 1080
# 13375565248934352031245861515653274879560267436972842215671280963977858996049651078858079966593024
# 0
# 12
# False
# True
# False
# True
# False
# True
# False
# True

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
English_marks=90
Islamiat_marks=85
Maths_marks=95
sum_marks= English_marks+Islamiat_marks+Maths_marks
Total_marks=300
calculated_precentage= sum_marks*100/Total_marks
print(calculated_precentage)
# Out:
# 90.0

# %% [markdown]
# 5. Take the values of two variables `a` and `b`, then swap their values without using a third variable and print the result before and after swapping

# %%
a=10
b=900
print(a)
print(b)
#print(a,"\n",b)
#before swapping
# take a third variable .Reason if we do it without it one of the main variable will lose its value.
c=a
a=b
b=a
print("a value is",a)
print("b value is",b)
# Out:
# 10
# 900
# a value is 900
# b value is 900

# %% [markdown]
# 6. Take the radius of a circle from a variable and calculate its Area and Circumference (use `pi = 3.14159`)

# %%
# CIRCLE AREA =PI*RADUES^2
#CIRCLE CIRCUMFERENCE =2*PI*RADIUS
import math
radius=r=10
area= math.pi*r**2
circumference= math.pi*2*r
print("area of circle is",area)
print("circumference of circle is",circumference)
# Out:
# area of circle is 314.1592653589793
# circumference of circle is 62.83185307179586

# %% [markdown]
# 7. Take the price of an item and a discount percentage in variables, then calculate and print the discount amount and the final price after discount

# %%
#before applying discount
item_price=120
discount_precentage=20/100
#after applying discount
discounted_amount=item_price*discount_precentage
discounted_price=item_price-discounted_amount
print("before discount\t:",item_price)
print("after discount\t:",discounted_price)
# Out:
# before discount	: 120
# afterdiscount	: 96.0

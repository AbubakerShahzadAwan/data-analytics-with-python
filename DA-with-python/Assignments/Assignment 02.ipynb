# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
salary=int(input("how much is your salary ?"))# 50000
years_of_working=int(input("how many years of work"))#12
if years_of_working>5:
    Increased_salary=salary + salary*5/100
    print(Increased_salary)
else :
    print("not inceased")

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age=int(input("what is your age"))# age enter is 19
if age>18:
    print("you are eligible for vote")
else :
    print("you are not eligible")
# Out:
# you are eligible for vote

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
number=int(input("enter the number"))
if number%2:                              # the % means the reminder what leftover after the divide  , if leftover is zero is even or vise vesa.
    print("the nuber is odd")   
else :
    print("the number is even")
# Out:
# the number is even

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
number=int(input("what is the number"))
if number%7:      # the number%7 means there is a leftover in whole number .
    print("it is not divisible ")
else:
    print("divisible")
# Out:
# it is not divisible

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
number=int(input("enter the number"))
if number%5 == 0:
    print("the number is multiple of 5")
else :
    print("not multiple of five")
# Out:
# the number is multiple of 5

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
number=int(input("enter the number"))
last_digit=number%10
print( "\tthe last digit is :\n",last_digit)
# Out:
# 	the last digit is :
#  3

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
lenght=int(input("what is the lenght of shape? "))
width=int(input("what is the width of shape?"))
if lenght==width:
    print("it is a square")
else :
    print("it is rectangle")
# Out:
# it is rectangle

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
first_number=int(input('what is the first number'))
second_number=int(input('what is the seconnd number'))
if first_number>second_number:
    print("first number is greater")
else :
    print("second number is greater")
# Out:
# second number is greater

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
items=int(input("how many items you want to buy"))


if total_price>1000:
    discount=items*10/100
    print("your discount is",discount)
else:
    print("no discount available")

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
marks=int(input("what is your marks"))
if marks>80:
    print("your grade is A")
elif marks <=80:
    print("your grade is B")
elif marks<=59:
    print("your grade is C")
elif marks<=49:
    print("your grade is D")
elif marks<=44:
    print("your grade is E")
elif marks<=25:
    print("your grade is F")
# Out:
# your grade is B

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
total_number_of_classes=int(input("what is total classes held"))
numbers_of_classes=int(input("how many classes has you attended?"))
attendence= (numbers_of_classes*100)/total_number_of_classes
if attendence>75:  
    print("you can sit in exam")
else :
    print("you are not allow to sit in exam")
# Out:
# you can sit in exam

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
medical_condition=input("do you have any medical condition?")

if medical_condition=='Y':  
    print("you can sit in exam")
elif medical_condition=='N':
    print("you are not allow to sit in exam")
# Out:
# you can sit in exam

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
years = int(input("which year"))
if years%4 ==0 :
    print("leap years")
else :
    print("no leap years")

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
gender=str(input("what your gender"))
marital_status=str(input("what your status?"))
age =int(input("what is your age?"))
if gender=="f" and marital_status=="y":
     print("urban only")
elif gender=="m"and 20<=age>=40 :
     print("work anywhere he want")
elif gender =="m" and 40<=age>=60:
     print("work in urban")
else :
     print("error")
# Out:
# work anywhere he want

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
first_person=int(input("your age ?"))
second_person=int(input("your age ?"))
third_person=int(input("your age ?"))
if first_person>second_person and first_person>third_person :
    print("oldest is first")
elif second_person>first_person and second_person>third_person :
    print("oldest is second") 
elif third_person>first_person and third_person>second_person :
    print("oldest is third")

if   first_person<second_person and first_person<third_person :
    print("youngest is first")  
elif second_person<first_person and second_person<third_person :
    print("youngest is second") 
elif third_person<first_person and third_person>second_person :
    print("youngest is third")
# Out:
# oldest is first
# ypungest is second
